# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure this is already loaded:
# df_combined = pd.concat([df_5mb, df_700kb], ignore_index=True)
# df_combined['Timestamp'] = pd.to_datetime(df_combined['Timestamp'])

sns.set(style="whitegrid")

# --- Plot 1: Upload Latency by File Size ---
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_combined, x='File Size', y='Upload (s)', palette=["#f4c542", "#ee8a3b"])
plt.title("Upload Latency by File Size")
plt.ylabel("Upload (s)")
plt.xlabel("File Size")
plt.tight_layout()
plt.savefig("Upload_Latency_Boxplot.png", dpi=300)
plt.show()

# --- Plot 2: Download Latency by File Size ---
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_combined, x='File Size', y='Download (s)', palette=["#f4c542", "#ee8a3b"])
plt.title("Download Latency by File Size")
plt.ylabel("Download (s)")
plt.xlabel("File Size")
plt.tight_layout()
plt.savefig("Download_Latency_Boxplot.png", dpi=300)
plt.show()

# --- Plot 3: Soundtrap Page Latency by File Size ---
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_combined, x='File Size', y='Soundtrap (ms)', palette=["#f4c542", "#ee8a3b"])
plt.title("Soundtrap Page Latency by File Size")
plt.ylabel("Soundtrap (ms)")
plt.xlabel("File Size")
plt.tight_layout()
plt.savefig("Soundtrap_Latency_Boxplot.png", dpi=300)
plt.show()

# --- Plot 4: Upload Latency Over Time ---
plt.figure(figsize=(18, 6))
sns.lineplot(data=df_combined, x='Timestamp', y='Upload (s)', hue='File Size', palette=["#f4c542", "#ee8a3b"])
plt.title("Upload Latency Over Time")
plt.ylabel("Upload (s)")
plt.xlabel("Timestamp")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Upload_Latency_Over_Time.png", dpi=300)
plt.show()

# --- Plot 5: Download Latency Over Time ---
plt.figure(figsize=(18, 6))
sns.lineplot(data=df_combined, x='Timestamp', y='Download (s)', hue='File Size', palette=["#f4c542", "#ee8a3b"])
plt.title("Download Latency Over Time")
plt.ylabel("Download (s)")
plt.xlabel("Timestamp")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Download_Latency_Over_Time.png", dpi=300)
plt.show()

# --- Plot 6: Soundtrap Page Latency Over Time ---
plt.figure(figsize=(18, 6))
sns.lineplot(data=df_combined, x='Timestamp', y='Soundtrap (ms)', hue='File Size', palette=["#f4c542", "#ee8a3b"])
plt.title("Soundtrap Page Latency Over Time")
plt.ylabel("Soundtrap (ms)")
plt.xlabel("Timestamp")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Soundtrap_Latency_Over_Time.png", dpi=300)
plt.show()
# Out:
# C:\Users\morga\AppData\Local\Temp\ipykernel_15572\184198451.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_combined, x='File Size', y='Upload (s)', palette=["#f4c542", "#ee8a3b"])
# C:\Users\morga\AppData\Local\Temp\ipykernel_15572\184198451.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_combined, x='File Size', y='Download (s)', palette=["#f4c542", "#ee8a3b"])
# C:\Users\morga\AppData\Local\Temp\ipykernel_15572\184198451.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
